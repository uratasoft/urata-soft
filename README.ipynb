# %% [markdown]
# # 付属データをお使いになる前にお読みください
#
# - 1.付属データについて
# - 2.本書のサンプルの動作環境
# - 3.Anacondaのインストール方法
# - 4.サンプルデータの一覧
# - 5.もっと勉強したい・調べたい方へ
# - 6.免責事項について

# %% [markdown]
# ## 1.付属データについて
# 　本書の付属データをダウンロードしていただきましてありがとうございます。<br>
# 　付属データには『Pythonで動かして学ぶ! あたらしいブロックチェーンの教科書』（ISBN978-4-7981-5944-7）の本文で解説したコードと演習問題および解答例のサンプルファイル（**第4章**から**第14章**、**第16章**、**章末問題**の解答）を用意しています。<br>
# 　サンプルコードを確認するにあたりまして、以下の点をご留意ください。<br>
#
# - サンプルはすべて<font color="MediumBlue">あくまで一例</font>を示したもので唯一の解を示したものではありません。
# - どんどん自分なりに改良したり、コードを綺麗にしたりして、ご自身の理解を深めてください。<font color="MediumBlue">サンプルコードの原型がなくなるまで、コードを触っていただけることを期待しています！　</font>
# - 一部書籍内で紹介できなかった内容やコードの最適化を行っていますが、大きな変更はしておりません。
#
# ### 1.1.サンプルファイルの形式
# 　サンプルファイルはJupyter Notebook形式です。<br>
# 　AnacondaやJupyter Notebookの起動方法などは本書の第3章をご覧ください。
#
# ### 1.2.Jupyter Notebookへのサンプルファイルの追加方法
# 　Jupyter Notebookを起動すると、［Files］タブの画面（Windows のエクスプローラーが起動）が開きます。<br>
# 　［Files］タブの画面にサンプルファイルをドラッグ＆ドロップして追加できます。追加したら［Upload］ボタンをクリックします。アップロードしたファイルをクリックすると編集画面が開きます。<br>
# 　［In］のボックスからコードをコピーできます。またファイル上で、実行結果も確認できます。<br>

# %% [markdown]
# ## 2.本書のサンプルの動作環境
# 　本書のサンプルは下表の環境で、問題なく動作することを確認しています。
#
# | 項目 | 内容 |
# |:-----------|:------------|
# | OS | macOS：Mojave 10.14.5　 |
# |    | Windows：10 Pro 1803　 |
# | CPU | macOS：2.7GHz Intel Core i7 |
# |     | Windows：3.7GHz Intel Core i7 |
# | メモリ | macOS：16 GB 2133 MHz LPDDR3 |
# |        | Windows：16GB |
# | GPU | macOS：Intel Iris Plus Graphics 655 1536 MB |
# |     | Windows：NVIDIA GeForce GTX 1060 6GB |
# | Anaconda（インストーラー） | macOS：Anaconda3-2019.03-MacOSX-x86_64.pkg |
# |                            | Windows：Anaconda3-2019.03-Windows-x86_64.exe |
#
#
# | 項目 | 内容 |
# |:-----------|:------------|
# | Python | 3.6 |
# | NumPy | 1.16.4 |
# | ecdsa | 0.13.2 |
# | base58 | 1.0.3 |
# | requests | 2.22.0 |

# %% [markdown]
# ## 3.Anacondaのインストール方法
# 　インストール方法はいたって単純で、以下の手順で行います。手順はmacOS、Windows、Linux共に同じです。
#
# - 1.Anaconda installer archiveのサイトへアクセス
# - 2.Anaconda3-2019.03のバージョンをダウンロード
#
# 　以下のURLからAnaconda installer archiveのサイトへアクセスして、使用しているOS名の付いたAnaconda3-2019.03のバージョンのインストーラーをダウンロードしましょう。
#
# - Anaconda installer archive<br>
# https://repo.continuum.io/archive/
#
# 　本書ではPythonのバージョンを3.6に固定しています。ダウンロードが済んだら、他のソフトウェアと同じようにインストールの手順を踏んでいきましょう。
#
# ### 3.1.ライブラリのインストール方法
# 　本書では、Anaconda Navigator上から`NumPy`や`ecdsa`などのライブラリをインストールしています（第1章を参照）。
#
# ### 3.2.ターミナルでライブラリを追加する方法
# 　作成した仮想環境を選択し、「▶」をクリックして、「Open Terminal」を選択します。ターミナルが起動しますので、以下のようにpipコマンドでパッケージのインストールを実行します。<br>
#
# ```
# $ pip install パッケージ名
# ```
#
# ### 3.3 セル上でライブラリを追加する方法
# 　Jupyter Notebookのセル上でパッケージをインストールする場合は、以下のように、`!`（エクスクラメーションマーク）を先頭に付け、pipコマンドでパッケージのインストールを実行します。<br>
#
# ```
# ! pip install パッケージ名
# ```

# %% [markdown]
# ## 4.サンプルデータの一覧
# 　サンプルデータのフォルダとファイル構成は次の通りです。zipファイルを解凍して利用してください。サンプルコードがない章や節は、収録していません。
#
# python_blockchain_sample.zip
#
#     +-- Chapter4【第4章のサンプルフォルダ】
#         +-- Chapter4.ipynb
#
#     +-- Chapter5【第5章のサンプルフォルダ】
#         +-- Chapter5.ipynb
#
#     +-- Chapter6【第6章のサンプルフォルダ】
#         +-- Chapter6.ipynb
#
#     +-- Chapter7【第7章のサンプルフォルダ】
#         +-- Chapter7.ipynb
#
#     +-- Chapter8【第8章のサンプルフォルダ】
#         +-- Chapter4.ipynb
#
#     +-- Chapter9【第9章のサンプルフォルダ】
#         +-- Chapter9.ipynb
#
#     +-- Chapter10【第10章のサンプルフォルダ】
#         +-- Chapter10.ipynb
#
#     +-- Chapter11【第11章のサンプルフォルダ】
#         +-- Chapter11.ipynb
#
#     +-- Chapter12【第12章のサンプルフォルダ】
#         +-- Chapter12.ipynb
#
#     +-- Chapter13【第13章のサンプルフォルダ】
#         +-- Chapter13.ipynb
#
#     +-- Chapter14【第14章のサンプルフォルダ】
#         +-- Chapter14.ipynb
#
#     +-- Chapter16【第16章のサンプルフォルダ:主にコマンド一覧】
#         +-- Chapter16.ipynb
#
#     +-- Shomatsumondai_kaitorei【章末問題の解答例のサンプルフォルダ】
#         +-- Chapter4_Shomatsumondai_kaitorei.ipynb
#         +-- Chapter7_Shomatsumondai_kaitorei.ipynb
#         +-- Chapter8_Shomatsumondai_kaitorei.ipynb
#         +-- Chapter9_Shomatsumondai_kaitorei.ipynb
#         +-- Chapter10_Shomatsumondai_kaitorei.ipynb
#         +-- Chapter13_Shomatsumondai_kaitorei.ipynb
#         +-- Chapter14_Shomatsumondai_kaitorei.ipynb
#         +-- mempool.json
#
#     +-- README.ipynb【本ファイル】

# %% [markdown]
# ## 5.もっと勉強したい・調べたい方へ
#
# ### 5.1.学習リソースを活用してみましょう。
# 　本書の218～220ページでおすすめの情報源（サイトなど）や学習サービスを紹介しています。<br>
# 　本書の内容や章末のダウンロードサンプルについて大枠がつかめた後は、これらのサイトにアクセスしてみることをお勧めします。<br>
#
# ### 5.2.参考文献
# 　以下の文献は、本書の執筆にあたり、とても参考にさせていただきました。<font color="MediumBlue">どの文献も非常によく書かれた良質なものばかりで、著者のみなさんのこだわりや魂を感じられるおすすめの文献です！</font><br>
# 　ぜひ本書で概要をつかんだ後は、これらの文献を読んでみて理解を深めてみてください。<br>
#
# - <b>Satoshi Nakamoto(2008)『Bitcoin: A Peer-to-Peer Electronic Cash System』</b>
#     - 右のリンクから閲覧できます。→　https://bitcoin.org/bitcoin.pdf
#     - ブロックチェーン技術の原点とも言える論文で、9ページの中に本書のすべてのエッセンスが含まれています。
#     - ぜひ読解に挑戦してみましょう！<br>
# <br>
# - <b>山崎重一郎、安土茂亨、田中俊太郎（2017）『ブロックチェーン・プログラミング　仮想通貨入門』、講談社</b>
#     - ブロックチェーンに関する知識がとても丁寧にまとめられています。
#     - 本書よりも発展的なため、本書で学び終えた後に挑戦してみましょう。
#     - 本書の221ページでも行っているフルノードの立ち上げについても詳しく解説されています。<br>
# <br>
# - <b>アンドレアス・M・アントノプロス (著)今井 崇也、鳩貝淳一郎 (翻訳)（2016）『Mastering Bitcoin ビットコインとブロックチェーン』、NTT出版</b>
#     - ビットコインのブロックチェーンに関して網羅的かつ詳細に解説されています。
#     - 内容はとても技術的なため、力試しとして挑戦してみるとよいでしょう。
#     - PDF版もインターネット上で公開されています。<br>
# <br>
# - <b>石川聡彦、永尾修一、中川聡（2019）『ブロックチェーンプログラミングのためのコンピュータサイエンスがわかる本』、KADOKAWA</b>
#     - ブロックチェーン技術に関連するさまざまな技術を解説しています。
#     - ブロックチェーンの理解にとても役立つ知識が詰め込まれているため、初学者には重宝します。
#     - 図表も多いため、直感的に理解しやすい点も初学者にとってありがたい1冊です。<br>
# <br>
# - <b>田篭照博（2018）『堅牢なシステム開発/運用を実現するための ビットコイン[技術]入門』、技術評論社</b>
#     - 暗号学をはじめセキュリティの観点からブロックチェーンを解説しています。
#     - OpenSSLというソフトウェアを利用して、実際に動かしながら学ぶことができます。
#     - 内容が技術よりなため、腕試しとして挑戦してみるとよいでしょう。

# %% [markdown]
# ## 6.免責事項について
# - 本書に記載されたURLなどは予告なく変更される場合があります。
# - 本書の出版にあたっては正確な記述につとめましたが、著者や出版社などのいずれも、本書の内容に対して何らかの保証をするものではなく、内容やサンプルにもとづくいかなる運用結果に関してもいっさいの責任を負いません。
# - 本書に記載されている会社名、製品名はそれぞれ各社の商標および登録商標です。
# - 本書の内容は、2019年9月執筆時点のものです。
#
#                                                                    2019年9月　株式会社翔泳社 編集部
